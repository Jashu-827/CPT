# %% [markdown]
# #Linked List: non cantagious datastructure
# #Memory allocate
#
# 1. single Linked list
# 2. double Linked list
# 3. circular s/d linked list
#
# #SLL
# head----->node1-----> node2----->tail/null

# %%
'''
class node:
  def __init__(self, data):
    self.data = data
    self.next=None
'''
# Out:
# '\nclass node:\n  def __init__(self, data):\n    self.data = data\n    self.next=None\n'

# %% [markdown]
# **Insertion**
# 1. At Begining
# 2. At End
# 3. At Position

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class LinkedList:
  def __init__(self):
    self.head = None
  def iab(self, data):
    new_node = Node(data)
    new_node.next = self.head
    self.head = new_node
    print(f"{data} inserted from begin.")
  def display(self):
    current = self.head
    if not current:
      print("List is empty")
      return
    while current:
      print(current.data, end="-->")
      current= current.next
    print("None")

ll=LinkedList()
while True:
  print("\n LinkedList - Insert at Begin.....")
  print("1. insert ")
  print("2. Display")
  print("3. Exit")
  choice= input("Enter your choice: ")
  if choice == '1':
    data = int(input("Enter a value to insert: "))
    ll.iab(data)
  elif choice=='2':
    ll.display()
  elif choice=='3':
    print("Exit the operation...")
    break
  else:
    print("Enter only .... 1/2/3")
# Out:
#  LinkedList - Insert at Begin.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 4
# Enter only .... 1/2/3
#
#  LinkedList - Insert at Begin.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 11
# 11 inserted from begin.
#
#  LinkedList - Insert at Begin.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 22
# 22 inserted from begin.
#
#  LinkedList - Insert at Begin.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 44
# 44 inserted from begin.
#
#  LinkedList - Insert at Begin.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 23
# 23 inserted from begin.
#
#  LinkedList - Insert at Begin.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 2
# 23-->44-->22-->11-->None
#
#  LinkedList - Insert at Begin.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 3
# Exit the operation...

# %% [markdown]
# Insertion at End

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class LinkedList:
  def __init__(self):
    self.head = None

  def iae(self, data):
    new_node = Node(data)
    if self.head is None:
      self.head = new_node
      print(f"{data} inserted at end/ will be first node.")
      return
    current = self.head
    while current.next:
      current = current.next
    current.next = new_node
    print(f"{data} inserted last.")

  def display(self):
    current = self.head
    if not current:
      print("List is empty")
      return
    while current:
      print(current.data, end="-->")
      current= current.next
    print("None")

ll=LinkedList()
while True:
  print("\n LinkedList - Insert at Ending.....")
  print("1. insert ")
  print("2. Display")
  print("3. Exit")
  choice= input("Enter your choice: ")
  if choice == '1':
    data = int(input("Enter a value to insert: "))
    ll.iae(data)
  elif choice=='2':
    ll.display()
  elif choice=='3':
    print("Exit the operation...")
    break
  else:
    print("Enter only .... 1/2/3")
# Out:
#  LinkedList - Insert at Begin.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 11
# 11 inserted at end/ will be first node.
#
#  LinkedList - Insert at Begin.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 22
# 22 inserted last.
#
#  LinkedList - Insert at Begin.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 33
# 33 inserted last.
#
#  LinkedList - Insert at Begin.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 2
# 11-->22-->33-->None
#
#  LinkedList - Insert at Begin.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 3
# Exit the operation...

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class LinkedList:
  def __init__(self):
    self.head = None

  def iap(self, data,pos):
    new_node = Node(data)
    if pos<0:
      print("Position min>=1")
      return
    if pos==1: # begin at
      new_node.next = self.head
      self.head = new_node
      print(f"{data} inserted at at pos-1.")
      return
    current = self.head
    c=1
    while current and c < pos-1:
      current = current.next
      c+=1
    if not current:
      print("Not in range...")
      return
    new_node.next = current.next
    current.next = new_node
    print(f"{data} inserted at pos-{pos}.")

  def display(self):
    current = self.head
    if not current:
      print("List is empty")
      return
    while current:
      print(current.data, end="-->")
      current= current.next
    print("None")

ll=LinkedList()
while True:
  print("\n LinkedList - Insert at Ending.....")
  print("1. insert ")
  print("2. Display")
  print("3. Exit")
  choice= input("Enter your choice: ")
  if choice == '1':
    data = int(input("Enter a value to insert: "))
    pos= int(input("Enter a position to insert: "))
    ll.iap(data,pos)
  elif choice=='2':
    ll.display()
  elif choice=='3':
    print("Exit the operation...")
    break
  else:
    print("Enter only .... 1/2/3")
# Out:
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 21
# Enter a position to insert: 1
# 21 inserted at at pos-1.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 23
# Enter a position to insert: 2
# 23 inserted at pos-2.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 33
# Enter a position to insert: 4
# Not in range...
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 2
# 21-->23-->None
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 3
# Exit the operation...

# %%
''' Search operation in linked list'''
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class LinkedList:
  def __init__(self):
    self.head = None

  def iae(self, data):
    new_node = Node(data)
    # if pos<0:
    #   print("Position min>=1")
    #   return
    # if pos==1: # begin at
    #   new_node.next = self.head
    #   self.head = new_node
    #   print(f"{data} inserted at at pos-1.")
    #   return
    # current = self.head
    # c=1
    # while current and c < pos-1:
    #   current = current.next
    #   c+=1
    # if not current:
    #   print("Not in range...")
    #   return
    # new_node.next = current.next
    # current.next = new_node
    # print(f"{data} inserted at pos-{pos}.")

  def search(self, key):
    pos=1
    current=self.head
    while current:
      if current.data==key:
        print(f"{key} found in the ll")
        return True
      current=current.next
      pos+=1
    print(f"{key} not found in the ll")
    return False

  def display(self):
    current = self.head
    if not current:
      print("List is empty")
      return
    while current:
      print(current.data, end="-->")
      current= current.next
    print("None")

ll=LinkedList()
while True:
  print("\n LinkedList - Insert at Ending.....")
  print("1. insert ")
  print("2. Display")
  print("3. Search")
  print("4. Exit")
  choice= input("Enter your choice: ")
  if choice == '1':
    data = int(input("Enter a value to insert: "))
    ll.iap(data)
  elif choice=='2':
    ll.display()
  elif choice=='3':
    val= int(input("Enter the value, you want search: "))
    ll.search(val)
  elif choice=='4':
    print("Exit the operation...")
    break
  else:
    print("Enter only .... 1/2/3/4")
# Out:
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Search
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 55
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-10-182650460.py in <cell line: 0>()
#      63   if choice == '1':
#      64     data = int(input("Enter a value to insert: "))
# ---> 65     ll.iap(data)
#      66   elif choice=='2':
#      67     ll.display()
#
# AttributeError: 'LinkedList' object has no attribute 'iap'

# %%
'''4 3 2 6 5 8 1 0 12 81'''
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class LinkedList:
  def __init__(self):
    self.head = None

  def iae(self, data):
    new_node = Node(data)
    if self.head is None:
      self.head = new_node
      print(f"{data} inserted at end/ will be first node.")
      return
    current = self.head
    while current.next:
      current = current.next
    current.next = new_node
    print(f"{data} inserted last.")

  def display(self):
    current = self.head
    if not current:
      print("List is empty")
      return
    while current:
      print(current.data, end="-->")
      current= current.next
    print("None")
  def mid_ele(self):
    pos=len(ll)//2
    print(ll[pos])
ll=LinkedList()
while True:
  print("\n LinkedList - Insert at Ending.....")
  print("1. insert ")
  print("2. Display")
  print("3. Exit")
  choice= input("Enter your choice: ")
  if choice == '1':
    data = int(input("Enter a value to insert: "))
    ll.iae(data)
  elif choice=='2':
    ll.display()
  elif choice=='4':
    ll.mid_ele()
  elif choice=='3':
    print("Exit the operation...")
    break
  else:
    print("Enter only .... 1/2/3")
# Out:
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 4
# 4 inserted at end/ will be first node.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 3
# 3 inserted last.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 2
# 2 inserted last.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 6
# 6 inserted last.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 5
# 5 inserted last.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 8
# 8 inserted last.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 1
# 1 inserted last.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 0
# 0 inserted last.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 12
# Enter only .... 1/2/3
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 81
# Enter only .... 1/2/3
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1-592026245.py in <cell line: 0>()
#      46     ll.display()
#      47   elif choice=='4':
# ---> 48     ll.mid_ele()
#      49   elif choice=='3':
#      50     print("Exit the operation...")
#
# /tmp/ipython-input-1-592026245.py in mid_ele(self)
#      31     print("None")
#      32   def mid_ele(self):
# ---> 33     pos=len(ll)//2
#      34     print(ll[pos])
#      35 ll=LinkedList()
#
# TypeError: object of type 'LinkedList' has no len()

# %%
'''4 3 2 6 5 8 1 0 12 81'''

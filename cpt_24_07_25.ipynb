# %% [markdown]
# Deleting operation by value

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class LinkedList:
  def __init__(self):
    self.head = None

  def iae(self, data):
    new_node = Node(data)
    if self.head is None:
      self.head = new_node
      print(f"{data} inserted at end/ will be first node.")
      return
    current = self.head
    while current.next:
      current = current.next
    current.next = new_node
    print(f"{data} inserted last.")

  def deletevalue(self, key):
    current = self.head
    if not current:
      print("List is empty")
      return
    if current.data == key:
      self.head = current.next
      print(f"{key} deleted from the list.")
      return
    prev = None
    while current and current.data != key:
      prev = current
      current = current.next
    if not current :
      print(f"{key} not found in the LL")
      return
    prev.next = current.next
    print(f"{key} deleted from the LL")

  def display(self):
    current = self.head
    if not current:
      print("List is empty")
      return
    while current:
      print(current.data, end="-->")
      current= current.next
    print("None")

ll=LinkedList()
while True:
  print("\n LinkedList - Insert at Ending.....")
  print("1. insert ")
  print("2. Display")
  print("3. Delete")
  print("4. Exit")
  choice= input("Enter your choice: ")
  if choice == '1':
    data = int(input("Enter a value to insert: "))
    ll.iae(data)
  elif choice=='2':
    ll.display()
  elif choice=='3':
    key=int(input("Enter the value, you want to delete: "))
    ll.deletevalue(key)
  elif choice=='4':
    print("Exit the operation...")
    break
  else:
    print("Enter only .... 1/2/3/4")
# Out:
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 21
# 21 inserted at end/ will be first node.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 32
# 32 inserted last.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 23
# 23 inserted last.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 45
# 45 inserted last.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 11
# 11 inserted last.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 12
# 12 inserted last.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 2
# 21-->32-->23-->45-->11-->12-->None
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 3
# Enter the value, you want to delete: 23
# 23 deleted from the LL
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 2
# 21-->32-->45-->11-->12-->None
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 4
# Exit the operation...

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class LinkedList:
  def __init__(self):
    self.head = None

  def iae(self, data):
    new_node = Node(data)
    if self.head is None:
      self.head = new_node
      print(f"{data} inserted at end/ will be first node.")
      return
    current = self.head
    while current.next:
      current = current.next
    current.next = new_node
    print(f"{data} inserted last.")

  def deletebegin(self):
    if self.head is None:
      print("Empty=LL")
    else:
      print("Deleted node from begin",self.head.data)
      self.head=self.head.next


  def display(self):
    current = self.head
    if not current:
      print("List is empty")
      return
    while current:
      print(current.data, end="-->")
      current= current.next
    print("None")

ll=LinkedList()
while True:
  print("\n LinkedList - Insert at Ending.....")
  print("1. insert ")
  print("2. Display")
  print("3. Delete")
  print("4. Exit")
  choice= input("Enter your choice: ")
  if choice == '1':
    data = int(input("Enter a value to insert: "))
    ll.iae(data)
  elif choice=='2':
    ll.display()
  elif choice=='3':
    ll.deletebegin()
  elif choice=='4':
    print("Exit the operation...")
    break
  else:
    print("Enter only .... 1/2/3/4")
# Out:
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Delete
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 11
# 11 inserted at end/ will be first node.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Delete
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 12
# 12 inserted last.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Delete
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 13
# 13 inserted last.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Delete
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 14
# 14 inserted last.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Delete
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 15
# 15 inserted last.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Delete
# 4. Exit
# Enter your choice: 2
# 11-->12-->13-->14-->15-->None
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Delete
# 4. Exit
# Enter your choice: 3
# Deleted node from begin 11
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Delete
# 4. Exit
# Enter your choice: 2
# 12-->13-->14-->15-->None
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Delete
# 4. Exit
# Enter your choice: 4
# Exit the operation...

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class LinkedList:
  def __init__(self):
    self.head = None

  def dae(self):
    if self.head is None:
      print("Empty=LL")
      return
    if self.head.next is None:
      print(f"Deleted last npode:{self.head.data}")
      self.head=None
      return
    current=self.head
    while current.next.next:
      current.next
    print(f"Deleted last node:{current.next.data}")
    current.next=None

  def iae(self, data):
    new_node = Node(data)
    if self.head is None:
      self.head = new_node
      print(f"{data} inserted at end/ will be first node.")
      return
    current = self.head
    while current.next:
      current = current.next
    current.next = new_node
    print(f"{data} inserted last.")

  def display(self):
    current = self.head
    if not current:
      print("List is empty")
      return
    while current:
      print(current.data, end="-->")
      current= current.next
    print("None")

ll=LinkedList()
while True:
  print("\n LinkedList - Insert at Ending.....")
  print("1. insert ")
  print("2. Display")
  print("3. Exit")
  choice= input("Enter your choice: ")
  if choice == '1':
    data = int(input("Enter a value to insert: "))
    ll.iae(data)
  elif choice=='2':
    ll.display()
  elif choice=='3':
    ll.dae()
  elif choice=='4':
    print("Exit the operation...")
    break
  else:
    print("Enter only .... 1/2/3/4")
# Out:
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 4
# Exit the operation...

# %%
class Transaction:
  def __init__(self, transaction_type, amount) :
    self.type=transaction_type
    self.amount=amount
    self.next=None

class TransactionHistory:
  def __init__(self):
    self.head=None
  def add_transaction(self, transaction_type, amount):
    nn= Transaction(transaction_type, amount)
    if not self.head:
      self.head=nn
    else:
      current=self.head
      while current.next:
        current=current.next
      current.next=nn
    print(f"{transaction_type} of Rs. {amount} recorded....")
  def show_history(self):
    if not self.head:
      print("No Transaction found......")
      return
    print("\n Transaction History ")
    current=self.head
    count=1
    while current:
      print(f"{count}, {current.type} - Rs{current.amount}")
      current=current.next
      count+=1
history = TransactionHistory()
while True:
  print('\n----------ATM Transaction Menu-------------')
  print("1. Deposit")
  print("2. withDraw")
  print("3. History")
  print("4. Exit")
  choice = input("Enter number: ")
  if choice =='1':
    amount=float(input("Enter amount to deposit: "))
    history.add_transaction("Deposit", amount)
  elif choice=='2':
    amount=float(input("Enter amount to withdraw: "))
    history.add_transaction("Withdraw ", amount)
  elif choice == '3':
    history.show_history()
  elif choice=='4':
    break
  else:
    print("Enter only 1/2/3/4")
# Out:
# ----------ATM Transaction Menu-------------
# 1. Deposit
# 2. withDraw
# 3. History
# 4. Exit
# Enter number: 1
# Enter amount to deposit: 1200
# Deposit of Rs. 1200.0 recorded....
#
# ----------ATM Transaction Menu-------------
# 1. Deposit
# 2. withDraw
# 3. History
# 4. Exit
# Enter number: 1
# Enter amount to deposit: 2500
# Deposit of Rs. 2500.0 recorded....
#
# ----------ATM Transaction Menu-------------
# 1. Deposit
# 2. withDraw
# 3. History
# 4. Exit
# Enter number: 1
# Enter amount to deposit: 500
# Deposit of Rs. 500.0 recorded....
#
# ----------ATM Transaction Menu-------------
# 1. Deposit
# 2. withDraw
# 3. History
# 4. Exit
# Enter number: 2
# Enter amount to withdraw: 200
# Withdraw  of Rs. 200.0 recorded....
#
# ----------ATM Transaction Menu-------------
# 1. Deposit
# 2. withDraw
# 3. History
# 4. Exit
# Enter number: 3
#
#  Transaction History
# 1, Deposit - Rs1200.0
# 2, Deposit - Rs2500.0
# 3, Deposit - Rs500.0
# 4, Withdraw  - Rs200.0
#
# ----------ATM Transaction Menu-------------
# 1. Deposit
# 2. withDraw
# 3. History
# 4. Exit
# Enter number: 4

# %%
'''
consider a single linked list with insert at end nodes
after insertion reverse the node to print
input - 11-22-33-44-55-null
output- 55-44-33-22-11-null
'''
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class LinkedList:
  def __init__(self):
    self.head = None

  def iae(self, data):
    new_node = Node(data)
    if self.head is None:
      self.head = new_node
      print(f"{data} inserted at end/ will be first node.")
      return
    current = self.head
    while current.next:
      current = current.next
    current.next = new_node
    print(f"{data} inserted last.")

  def display(self):
    current = self.head
    if not current:
      print("List is empty")
      return
    while current:
      print(current.data, end="-->")
      current= current.next
    print("Null")

  def reversed_LL(self) :
    current=self.head
    prev=None
    if not current:
      print("LL is empty")
      return

    while current:
      next=current.next
      current.next=prev
      prev=current
      current=current.next
      print(prev)
      return prev
  def display

ll=LinkedList()
while True:
  print("\n LinkedList - Insert at Ending.....")
  print("1. insert ")
  print("2. Display")
  print("3. Exit")
  choice= input("Enter your choice: ")
  if choice == '1':
    data = int(input("Enter a value to insert: "))
    ll.iae(data)
  elif choice=='2':
    ll.display()
  elif choice=='3':
    ll.reversed_LL()
  elif choice=='4':
    print("Exit the operation...")
    break
  else:
    print("Enter only .... 1/2/3")
# Out:
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 11
# 11 inserted at end/ will be first node.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 12
# 12 inserted last.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 2
# 11-->12-->Null
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 3
# <__main__.Node object at 0x7e8973efed10>
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 4
# Exit the operation...

# %%
1111
